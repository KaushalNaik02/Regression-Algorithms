# %% [markdown]
# #### Simple Linear Regression Problem 01

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data = {
    'YearsExperience': [1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.3, 3.8, 4.0, 4.1, 4.5, 5.0, 5.2],
    'Salary': [39343, 46205, 37731, 43525, 39891, 56642, 60150, 54445, 64445, 57189, 56957, 57081, 61111, 67938, 66029]
}
df = pd.DataFrame(data)

# %%
X = df[['YearsExperience']]
Y = df['Salary']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
Y_train
# Out:
# 13    67938
# 5     56642
# 8     64445
# 2     37731
# 1     46205
# 14    66029
# 4     39891
# 7     54445
# 10    56957
# 12    61111
# 3     43525
# 6     60150
# Name: Salary, dtype: int64

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test,Y_pred)
r2_score = r2_score(Y_test,Y_pred)

# %%
print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2_score}")
# Out:
# Mean Squared Error: 6357726.7484399555
# R² Score: 0.9096240593261757

# %%
plt.scatter(X_train, Y_train, color='blue', label="Training Data")
plt.scatter(X_test, Y_test, color='red', label="Testing Data")
plt.plot(X, model.predict(X), color='green', label="Regression Line")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Simple Linear Regression: Salary vs Experience")
plt.legend()
plt.show()
